# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %pylab inline

# %%
DEATHS_JOIN = pd.read_csv("ALL_JOIN_UGLY.csv")

# %%
DEATHS_JOIN
# Out:
#            State Name  Year  Yearly_Avg_AQI  Yearly_Avg_COVID_Multiple_Cause  \
# 0             Alabama  2020            24.6                           133.25
# 1             Alabama  2021            26.1                           133.25
# 2             Alabama  2022             9.5                           133.25
# 3             Alabama  2020            24.6                           101.67
# 4             Alabama  2021            26.1                           101.67
# ...               ...   ...             ...                              ...
# 213995  West Virginia  2020            15.3                            74.00
# 213996  West Virginia  2022            14.7                            53.00
# 213997  West Virginia  2021            18.8                            53.00
# 213998  West Virginia  2020            15.3                            53.00
# 213999  West Virginia  2022            14.7                            37.80
#
#         Yearly_Avg_COVID_Underlying_Cause  \
# 0                                  122.42
# 1                                  122.42
# 2                                  122.42
# 3                                   86.00
# 4                                   86.00
# ...                                   ...
# 213995                              65.83
# 213996                              42.22
# 213997                              42.22
# 213998                              42.22
# 213999                              34.40
#
#         Yearly_Avg_Other_Respiratory_Causes  \
# 0                                     17.83
# 1                                     17.83
# 2                                     17.83
# 3                                     19.67
# 4                                     19.67
# ...                                     ...
# 213995                                12.33
# 213996                                 0.00
# 213997                                 0.00
# 213998                                 0.00
# 213999                                11.00
#
#         Yearly_Avg_Chronic_Lower_Respiratory_Diseases_Causes  \
# 0                                                   64.25
# 1                                                   64.25
# 2                                                   64.25
# 3                                                   56.11
# 4                                                   56.11
# ...                                                   ...
# 213995                                              29.25
# 213996                                              30.33
# 213997                                              30.33
# 213998                                              30.33
# 213999                                              30.92
#
#         Yearly_Avg_Flu_Pneumonia_Causes  Population aqi_index
# 0                                 20.00        2368      Good
# 1                                 20.00        2368      Good
# 2                                 20.00        2368      Good
# 3                                 15.78        2368      Good
# 4                                 15.78        2368      Good
# ...                                 ...         ...       ...
# 213995                            11.25        5726      Good
# 213996                            12.25        3847      Good
# 213997                            12.25        3847      Good
# 213998                            12.25        3847      Good
# 213999                            13.13        3847      Good
#
# [214000 rows x 10 columns]

# %%
# Set the 'Country Code' to be our index for easy referencing of rows
combined_data = DEATHS_JOIN.set_index("State Name")

# %%
# Collect the mean aqi rates for the world
average_deaths_aqi = DEATHS_JOIN['Yearly_Avg_AQI'].mean()

# %%
average_deaths_aqi
# Out:
# 24.662065887841038

# %%
uniqueValues = (DEATHS_JOIN['State Name'].append(DEATHS_JOIN['Year'])).unique()
# Out:
# C:\Users\lorai\AppData\Local\Temp\ipykernel_13416\1633826976.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   uniqueValues = (DEATHS_JOIN['State Name'].append(DEATHS_JOIN['Year'])).unique()

# %%
uniqueValues
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'New York', 'Ohio', 'Oklahoma', 'South Carolina',
#        'South Dakota', 'Texas', 'West Virginia', 'Wisconsin', 'Nebraska',
#        'Nevada', 'New Hampshire', 'New Jersey', 'North Dakota',
#        'Pennsylvania', 'Montana', 'Tennessee', 'Washington', 2020, 2021,
#        2022], dtype=object)

# %%
DEATHS_JOIN.drop_duplicates()
# Out:
#            State Name  Year  Yearly_Avg_AQI  Yearly_Avg_COVID_Multiple_Cause  \
# 0             Alabama  2020            24.6                           133.25
# 1             Alabama  2021            26.1                           133.25
# 2             Alabama  2022             9.5                           133.25
# 3             Alabama  2020            24.6                           101.67
# 4             Alabama  2021            26.1                           101.67
# ...               ...   ...             ...                              ...
# 213995  West Virginia  2020            15.3                            74.00
# 213996  West Virginia  2022            14.7                            53.00
# 213997  West Virginia  2021            18.8                            53.00
# 213998  West Virginia  2020            15.3                            53.00
# 213999  West Virginia  2022            14.7                            37.80
#
#         Yearly_Avg_COVID_Underlying_Cause  \
# 0                                  122.42
# 1                                  122.42
# 2                                  122.42
# 3                                   86.00
# 4                                   86.00
# ...                                   ...
# 213995                              65.83
# 213996                              42.22
# 213997                              42.22
# 213998                              42.22
# 213999                              34.40
#
#         Yearly_Avg_Other_Respiratory_Causes  \
# 0                                     17.83
# 1                                     17.83
# 2                                     17.83
# 3                                     19.67
# 4                                     19.67
# ...                                     ...
# 213995                                12.33
# 213996                                 0.00
# 213997                                 0.00
# 213998                                 0.00
# 213999                                11.00
#
#         Yearly_Avg_Chronic_Lower_Respiratory_Diseases_Causes  \
# 0                                                   64.25
# 1                                                   64.25
# 2                                                   64.25
# 3                                                   56.11
# 4                                                   56.11
# ...                                                   ...
# 213995                                              29.25
# 213996                                              30.33
# 213997                                              30.33
# 213998                                              30.33
# 213999                                              30.92
#
#         Yearly_Avg_Flu_Pneumonia_Causes  Population aqi_index
# 0                                 20.00        2368      Good
# 1                                 20.00        2368      Good
# 2                                 20.00        2368      Good
# 3                                 15.78        2368      Good
# 4                                 15.78        2368      Good
# ...                                 ...         ...       ...
# 213995                            11.25        5726      Good
# 213996                            12.25        3847      Good
# 213997                            12.25        3847      Good
# 213998                            12.25        3847      Good
# 213999                            13.13        3847      Good
#
# [121760 rows x 10 columns]

# %%
DEATHS_JOIN.groupby(['Yearly_Avg_AQI','Population'])

# %%
# Out:
#            State Name  Year  Yearly_Avg_AQI  Yearly_Avg_COVID_Multiple_Cause  \
# 0             Alabama  2020            24.6                           133.25
# 1             Alabama  2021            26.1                           133.25
# 2             Alabama  2022             9.5                           133.25
# 3             Alabama  2020            24.6                           101.67
# 4             Alabama  2021            26.1                           101.67
# ...               ...   ...             ...                              ...
# 213995  West Virginia  2020            15.3                            74.00
# 213996  West Virginia  2022            14.7                            53.00
# 213997  West Virginia  2021            18.8                            53.00
# 213998  West Virginia  2020            15.3                            53.00
# 213999  West Virginia  2022            14.7                            37.80
#
#         Yearly_Avg_COVID_Underlying_Cause  \
# 0                                  122.42
# 1                                  122.42
# 2                                  122.42
# 3                                   86.00
# 4                                   86.00
# ...                                   ...
# 213995                              65.83
# 213996                              42.22
# 213997                              42.22
# 213998                              42.22
# 213999                              34.40
#
#         Yearly_Avg_Other_Respiratory_Causes  \
# 0                                     17.83
# 1                                     17.83
# 2                                     17.83
# 3                                     19.67
# 4                                     19.67
# ...                                     ...
# 213995                                12.33
# 213996                                 0.00
# 213997                                 0.00
# 213998                                 0.00
# 213999                                11.00
#
#         Yearly_Avg_Chronic_Lower_Respiratory_Diseases_Causes  \
# 0                                                   64.25
# 1                                                   64.25
# 2                                                   64.25
# 3                                                   56.11
# 4                                                   56.11
# ...                                                   ...
# 213995                                              29.25
# 213996                                              30.33
# 213997                                              30.33
# 213998                                              30.33
# 213999                                              30.92
#
#         Yearly_Avg_Flu_Pneumonia_Causes  Population aqi_index
# 0                                 20.00        2368      Good
# 1                                 20.00        2368      Good
# 2                                 20.00        2368      Good
# 3                                 15.78        2368      Good
# 4                                 15.78        2368      Good
# ...                                 ...         ...       ...
# 213995                            11.25        5726      Good
# 213996                            12.25        3847      Good
# 213997                            12.25        3847      Good
# 213998                            12.25        3847      Good
# 213999                            13.13        3847      Good
#
# [214000 rows x 10 columns]
