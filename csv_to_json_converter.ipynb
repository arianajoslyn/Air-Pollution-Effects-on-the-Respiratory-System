# %%
import pandas as pd

# %%
data = pd.read_csv("Cleaned_DB_Data/ALL_JOIN_UGLY.csv")
data.head()
# Out:
#   State Name  Year  Yearly_Avg_AQI  Yearly_Avg_COVID_Multiple_Cause  \
# 0    Alabama  2020            24.6                           133.25
# 1    Alabama  2021            26.1                           133.25
# 2    Alabama  2022             9.5                           133.25
# 3    Alabama  2020            24.6                           101.67
# 4    Alabama  2021            26.1                           101.67
#
#    Yearly_Avg_COVID_Underlying_Cause  Yearly_Avg_Other_Respiratory_Causes  \
# 0                             122.42                                17.83
# 1                             122.42                                17.83
# 2                             122.42                                17.83
# 3                              86.00                                19.67
# 4                              86.00                                19.67
#
#    Yearly_Avg_Chronic_Lower_Respiratory_Diseases_Causes  \
# ...

# %%
data.to_json("Cleaned_DB_Data/ALL_JOIN_UGLY.json",orient = "records")
